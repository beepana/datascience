# %% [markdown]
#  # Day 10
#  ----

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
# !ls
# Out:
# 123.jpg                          Pandas II.ipynb
# 123.png                          Pandas III.ipynb
# API_EN.ATM.CO2E.KT_DS2_en_csv_v2 Pandas IV.ipynb
# Day 1.ipynb                      Problems
# Day 10.ipynb                     README.md
# Day 9.ipynb                      References
# Day-02-beepana.ipynb             Untitled.ipynb
# Day-03-beepana.ipynb             Untitled1.ipynb
# Day-04-numpy.ipynb               boston_house_prices.csv
# Day-07.ipynb                     data.sqlite3
# Day-08.ipynb                     datasets.h5
# Day-6-beepana.ipynb              day-05-beepana.ipynb
# LICENSE                          environment.yml
# Matplotlib II.ipynb              exercises.ipynb
# Numpy I.ipynb                    names.csv
# Numpy II.ipynb                   uni01-numpy-session.ipynb
# Numpy III and Matplotlib I.ipynb unit-01-data-session.ipynb
# Pandas I.ipynb                   unit-03-numpy.ipynb

# %%
# %ls
# Out:
# 123.jpg                           Pandas II.ipynb
# 123.png                           Pandas III.ipynb
# API_EN.ATM.CO2E.KT_DS2_en_csv_v2/ Pandas IV.ipynb
# Day 1.ipynb                       Problems/
# Day 10.ipynb                      README.md
# Day 9.ipynb                       References/
# Day-02-beepana.ipynb              Untitled.ipynb
# Day-03-beepana.ipynb              Untitled1.ipynb
# Day-04-numpy.ipynb                boston_house_prices.csv
# Day-07.ipynb                      data.sqlite3
# Day-08.ipynb                      datasets.h5
# Day-6-beepana.ipynb               day-05-beepana.ipynb
# LICENSE                           environment.yml
# Matplotlib II.ipynb               exercises.ipynb
# Numpy I.ipynb                     names.csv
# Numpy II.ipynb                    uni01-numpy-session.ipynb
# Numpy III and Matplotlib I.ipynb  unit-01-data-session.ipynb
# Pandas I.ipynb                    unit-03-numpy.ipynb

# %%
pd.read_csv('Metadata_Country_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Upper middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# 5            ARB                         NaN                  NaN
# 6            ARE  Middle East & North Africa          High income
# 7            ARG   Latin America & Caribbean  Upper middle income
# 8            ARM       Europe & Central Asia  Lower middle income
# 9            ASM         East Asia & Pacific  Upper middle income
# 10           ATG   Latin America & Caribbean          High income
# 11           AUS         East Asia & Pacific          High income
# 12           AUT       Europe & Central Asia          High income
# ...

# %%
pd.read_csv('Metadata_Indicator_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
# Out:
#    INDICATOR_CODE      INDICATOR_NAME  \
# 0  EN.ATM.CO2E.KT  CO2 emissions (kt)
#
#                                          SOURCE_NOTE  \
# 0  Carbon dioxide emissions are those stemming fr...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  Carbon Dioxide Information Analysis Center, En...         NaN

# %%
df = pd.read_csv('API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-13-dee1dd4fe172> in <module>()
# ----> 1 df = pd.read_csv('API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')
#
# ...

# %%
# !head API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv
# Out:
# ﻿"Data Source","World Development Indicators",
#
# "Last Updated Date","2017-03-23",
#
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016",
# "Aruba","ABW","CO2 emissions (kt)","EN.ATM.CO2E.KT","","","","","","","","","","","","","","","","","","","","","","","","","","","179.683","447.374","612.389","649.059","1730.824","1771.161","1558.475","1602.479","1595.145","1609.813","1617.147","1650.15","1712.489","1749.159","2321.211","2357.881","2372.549","2416.553","2420.22","2497.227","2497.227","2592.569","2508.228","2522.896","2456.89","2438.555","1301.785","876.413","","","",
# ...

# %%
df = pd.read_csv('API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv',skiprows=4)

# %%
df
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                              Andorra          AND
# 2                                          Afghanistan          AFG
# 3                                               Angola          AGO
# 4                                              Albania          ALB
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
df.head()
# Out:
#   Country Name Country Code      Indicator Name  Indicator Code      1960  \
# 0        Aruba          ABW  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 1      Andorra          AND  CO2 emissions (kt)  EN.ATM.CO2E.KT       NaN
# 2  Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT   414.371
# 3       Angola          AGO  CO2 emissions (kt)  EN.ATM.CO2E.KT   550.050
# 4      Albania          ALB  CO2 emissions (kt)  EN.ATM.CO2E.KT  2024.184
#
#        1961      1962      1963      1964      1965     ...            2008  \
# 0       NaN       NaN       NaN       NaN       NaN     ...        2508.228
# 1       NaN       NaN       NaN       NaN       NaN     ...         539.049
# 2   491.378   689.396   707.731   839.743  1008.425     ...        4217.050
# 3   454.708  1180.774  1151.438  1224.778  1188.108     ...       25709.337
# 4  2280.874  2464.224  2082.856  2016.850  2174.531     ...        4374.731
#
# ...

# %%
df[df["Country Name"]=='Nepal']
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code    1960  \
# 176        Nepal          NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT  80.674
#
#        1961    1962    1963     1964     1965     ...           2008  \
# 176  80.674  88.008  99.009  150.347  179.683     ...       3421.311
#
#          2009      2010      2011      2012      2013  2014  2015  2016  \
# 176  4334.394  5056.793  5533.503  5845.198  6501.591   NaN   NaN   NaN
#
#      Unnamed: 61
# 176          NaN
#
# [1 rows x 62 columns]

# %%
ndf = df[df["Country Name"]=='Nepal']

# %%
ndf.plot()
# Out:
# /Users/beepanapokharel/anaconda/lib/python3.6/site-packages/matplotlib/axes/_base.py:2903: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=176.0, right=176.0
#   'left=%s, right=%s') % (left, right))

# %%
ndf.drop(['Indicator Name','Country Code','Indicator Name','Country Name'],axis=1,inplace=True)
# Out:
# /Users/beepanapokharel/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ndf.drop(['Indicator Code'],axis=1,inplace=True)
# Out:
# /Users/beepanapokharel/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
ndf
# Out:
#        1960    1961    1962    1963     1964     1965     1966     1967  \
# 176  80.674  80.674  88.008  99.009  150.347  179.683  190.684  212.686
#
#         1968     1969     ...           2008      2009      2010      2011  \
# 176  253.023  399.703     ...       3421.311  4334.394  5056.793  5533.503
#
#          2012      2013  2014  2015  2016  Unnamed: 61
# 176  5845.198  6501.591   NaN   NaN   NaN          NaN
#
# [1 rows x 58 columns]

# %%
ndf = ndf.T

# %%
ndf.tail()
# Out:
#                   176
# 2013         6501.591
# 2014              NaN
# 2015              NaN
# 2016              NaN
# Unnamed: 61       NaN

# %%
ndf.columns = ['Emission']

# %%
ndf.dropna(inplace=True)

# %%
ndf
# Out:
#       Emission
# 1960    80.674
# 1961    80.674
# 1962    88.008
# 1963    99.009
# 1964   150.347
# 1965   179.683
# 1966   190.684
# 1967   212.686
# 1968   253.023
# 1969   399.703
# 1970   227.354
# 1971   198.018
# 1972   267.691
# 1973   421.705
# 1974   425.372
# 1975   352.032
# 1976   282.359
# 1977   337.364
# 1978   330.030
# 1979   513.380
# 1980   542.716
# 1981   454.708
# 1982   443.707
# 1983   495.045
# 1984   704.064
# 1985   678.395
# 1986   704.064
# 1987   872.746
# 1988   993.757
# 1989   913.083
# 1990   634.391
# 1991   960.754
# 1992  1331.121
# 1993  1466.800
# 1994  1697.821
# 1995  2035.185
# 1996  2486.226
# 1997  2783.253
# 1998  2251.538
# 1999  3219.626
# 2000  3069.279
# 2001  3267.297
# 2002  2625.572
# 2003  2841.925
# 2004  2669.576
# 2005  3083.947
# 2006  2563.233
# 2007  2614.571
# 2008  3421.311
# 2009  4334.394
# 2010  5056.793
# 2011  5533.503
# 2012  5845.198
# 2013  6501.591

# %%
ndf.plot()

# %%
ndf.index
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013'],
#       dtype='object')

# %%
df
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                              Andorra          AND
# 2                                          Afghanistan          AFG
# 3                                               Angola          AGO
# 4                                              Albania          ALB
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# ...

# %%
df1 = pd.read_csv('Metadata_Country_API_EN.ATM.CO2E.KT_DS2_en_csv_v2.csv')

# %%
df1
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Upper middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# 5            ARB                         NaN                  NaN
# 6            ARE  Middle East & North Africa          High income
# 7            ARG   Latin America & Caribbean  Upper middle income
# 8            ARM       Europe & Central Asia  Lower middle income
# 9            ASM         East Asia & Pacific  Upper middle income
# 10           ATG   Latin America & Caribbean          High income
# 11           AUS         East Asia & Pacific          High income
# 12           AUT       Europe & Central Asia          High income
# ...

# %%
sdf = df1[df1["Region"]=='South Asia']

# %%
sdf
# Out:
#     Country Code      Region          IncomeGroup  \
# 1            AFG  South Asia           Low income
# 18           BGD  South Asia  Lower middle income
# 30           BTN  South Asia  Lower middle income
# 107          IND  South Asia  Lower middle income
# 136          LKA  South Asia  Lower middle income
# 150          MDV  South Asia  Upper middle income
# 176          NPL  South Asia           Low income
# 182          PAK  South Asia  Lower middle income
#
#                                           SpecialNotes    TableName  \
# 1    Fiscal year end: March 20; reporting period fo...  Afghanistan
# 18   Fiscal year end: June 30; reporting period for...   Bangladesh
# 30   April 2013 database update: Data were updated ...       Bhutan
# 107  Fiscal year end: March 31; reporting period fo...        India
# 136  Bureau of Census and Statistics revised nation...    Sri Lanka
# 150  April 2012 database update: The Department of ...     Maldives
# ...

# %%
a1 =(sdf["Country Code"])

# %%
a1
# Out:
# 1      AFG
# 18     BGD
# 30     BTN
# 107    IND
# 136    LKA
# 150    MDV
# 176    NPL
# 182    PAK
# Name: Country Code, dtype: object

# %%
sa1 = pd.DataFrame
for values in a1:
    print(values)
    pd.concat(sa1,(df[df["Country Code"]==str(values)]))
sa1
# Out:
# AFG
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-7d1a601cc482> in <module>()
#       2 for values in a1:
#       3     print(values)
# ----> 4     pd.concat(sa1,(df[df["Country Code"]==str(values)]))
#       5 sa1
#
# /Users/beepanapokharel/anaconda/lib/python3.6/site-packages/pandas/tools/merge.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, copy)
#    1449                        keys=keys, levels=levels, names=names,
#    1450                        verify_integrity=verify_integrity,
# -> 1451                        copy=copy)
#    1452     return op.get_result()
#    1453
#
# /Users/beepanapokharel/anaconda/lib/python3.6/site-packages/pandas/tools/merge.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy)
# ...

# %%
sa1= df[df['Country Code'].isin(a1.values)]

# %%
sa1
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code        1960  \
# 2    Afghanistan          AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT     414.371
# 18    Bangladesh          BGD  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 30        Bhutan          BTN  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 106        India          IND  CO2 emissions (kt)  EN.ATM.CO2E.KT  120581.961
# 136    Sri Lanka          LKA  CO2 emissions (kt)  EN.ATM.CO2E.KT    2258.872
# 150     Maldives          MDV  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# 176        Nepal          NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT      80.674
# 182     Pakistan          PAK  CO2 emissions (kt)  EN.ATM.CO2E.KT   14154.620
#
#            1961        1962        1963        1964        1965     ...       \
# 2       491.378     689.396     707.731     839.743    1008.425     ...
# 18          NaN         NaN         NaN         NaN         NaN     ...
# ...

# %%
sa1.set_index("Country Name",inplace=True)

# %%
sa1
# Out:
#              Country Code      Indicator Name  Indicator Code        1960  \
# Country Name
# Afghanistan           AFG  CO2 emissions (kt)  EN.ATM.CO2E.KT     414.371
# Bangladesh            BGD  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# Bhutan                BTN  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# India                 IND  CO2 emissions (kt)  EN.ATM.CO2E.KT  120581.961
# Sri Lanka             LKA  CO2 emissions (kt)  EN.ATM.CO2E.KT    2258.872
# Maldives              MDV  CO2 emissions (kt)  EN.ATM.CO2E.KT         NaN
# Nepal                 NPL  CO2 emissions (kt)  EN.ATM.CO2E.KT      80.674
# Pakistan              PAK  CO2 emissions (kt)  EN.ATM.CO2E.KT   14154.620
#
#                     1961        1962        1963        1964        1965  \
# Country Name
# Afghanistan      491.378     689.396     707.731     839.743    1008.425
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# ...

# %%
sa1.drop(['Country Code','Indicator Code','Indicator Name'],inplace=True,axis=1)
# Out:
# /Users/beepanapokharel/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
sa1
# Out:
#                     1960        1961        1962        1963        1964  \
# Country Name
# Afghanistan      414.371     491.378     689.396     707.731     839.743
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# Bhutan               NaN         NaN         NaN         NaN         NaN
# India         120581.961  130402.187  143467.708  154083.673  150647.694
# Sri Lanka       2258.872    2335.879    2563.233    2533.897    2273.540
# Maldives             NaN         NaN         NaN         NaN         NaN
# Nepal             80.674      80.674      88.008      99.009     150.347
# Pakistan       14154.620   14656.999   16105.464   18514.683   19035.397
#
#                     1965        1966        1967        1968        1969  \
# Country Name
# Afghanistan     1008.425    1092.766    1283.450    1224.778     942.419
# Bangladesh           NaN         NaN         NaN         NaN         NaN
# ...

# %%
sa1 = sa1.T

# %%
sa1.plot()

# %%
sdf = sa1[['Bangladesh','Nepal','Pakistan','Bhutan']]

# %%
sdf
# Out:
# Country Name  Bangladesh     Nepal    Pakistan   Bhutan
# 1960                 NaN    80.674   14154.620      NaN
# 1961                 NaN    80.674   14656.999      NaN
# 1962                 NaN    88.008   16105.464      NaN
# 1963                 NaN    99.009   18514.683      NaN
# 1964                 NaN   150.347   19035.397      NaN
# 1965                 NaN   179.683   19974.149      NaN
# 1966                 NaN   190.684   20326.181      NaN
# 1967                 NaN   212.686   21572.961      NaN
# 1968                 NaN   253.023   24737.582      NaN
# 1969                 NaN   399.703   23993.181      NaN
# 1970                 NaN   227.354   24337.879    3.667
# 1971                 NaN   198.018   23076.431    3.667
# 1972            3509.319   267.691   18929.054    3.667
# 1973            4554.414   421.705   20036.488    3.667
# 1974            4660.757   425.372   21418.947    3.667
# 1975            4869.776   352.032   23219.444    3.667
# ...

# %%
sdf.dropna(inplace=True)
# Out:
# /Users/beepanapokharel/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
import seaborn as sns
sns.set()

# %%
sdf.plot()

# %%
sdf
# Out:
# Country Name  Bangladesh     Nepal    Pakistan   Bhutan
# 1972            3509.319   267.691   18929.054    3.667
# 1973            4554.414   421.705   20036.488    3.667
# 1974            4660.757   425.372   21418.947    3.667
# 1975            4869.776   352.032   23219.444    3.667
# 1976            5570.173   282.359   22838.076    3.667
# 1977            5812.195   337.364   24389.217    7.334
# 1978            6017.547   330.030   26138.376   11.001
# 1979            6648.271   513.380   28250.568   22.002
# 1980            7638.361   542.716   32067.915   22.002
# 1981            7931.721   454.708   34400.127   25.669
# 1982            8599.115   443.707   37385.065   33.003
# 1983            8236.082   495.045   40303.997   29.336
# 1984            9123.496   704.064   42856.229   51.338
# 1985           10234.597   678.395   47175.955   62.339
# 1986           11463.042   704.064   49453.162   55.005
# 1987           11862.745   872.746   53534.533  102.676
# ...

# %%
sdf['Bangladesh'].colsums
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-c6e73a8035a8> in <module>()
# ----> 1 sdf['Bangladesh'].colsums
#
# /Users/beepanapokharel/anaconda/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'colsums'

# %%
a1=(sdf['Bangladesh'].values.sum(),sdf['Nepal'].values.sum(),sdf['Pakistan'].values.sum(),sdf['Bhutan'].values.sum())

# %%
sdf.loc['2003':'2013']
# Out:
# Country Name  Bangladesh     Nepal    Pakistan   Bhutan
# 2003           35672.576  2841.925  118895.141  377.701
# 2004           37704.094  2669.576  131601.296  308.028
# 2005           39478.922  3083.947  136636.087  396.036
# 2006           43541.958  2563.233  146074.945  392.369
# 2007           44407.370  2614.571  158894.777  392.369
# 2008           49559.505  3421.311  159070.793  421.705
# 2009           53824.226  4334.394  158836.105  388.702
# 2010           59992.120  5056.793  161395.671  487.711
# 2011           63571.112  5533.503  162008.060  733.400
# 2012           67480.134  5845.198  163060.489  817.741
# 2013           68950.601  6501.591  153368.608  883.747

# %%
sdf.loc['2003':'2013'].sum(axis=1)
# Out:
# 2003    157787.343
# 2004    172282.994
# 2005    179594.992
# 2006    192572.505
# 2007    206309.087
# 2008    212473.314
# 2009    217383.427
# 2010    226932.295
# 2011    231846.075
# 2012    237203.562
# 2013    229704.547
# dtype: float64

# %%
sdf.loc['2003':'2013'].sum(axis=1).plot(kind="bar")

# %%
sdf
# Out:
# Country Name  Bangladesh     Nepal    Pakistan   Bhutan
# 1972            3509.319   267.691   18929.054    3.667
# 1973            4554.414   421.705   20036.488    3.667
# 1974            4660.757   425.372   21418.947    3.667
# 1975            4869.776   352.032   23219.444    3.667
# 1976            5570.173   282.359   22838.076    3.667
# 1977            5812.195   337.364   24389.217    7.334
# 1978            6017.547   330.030   26138.376   11.001
# 1979            6648.271   513.380   28250.568   22.002
# 1980            7638.361   542.716   32067.915   22.002
# 1981            7931.721   454.708   34400.127   25.669
# 1982            8599.115   443.707   37385.065   33.003
# 1983            8236.082   495.045   40303.997   29.336
# 1984            9123.496   704.064   42856.229   51.338
# 1985           10234.597   678.395   47175.955   62.339
# 1986           11463.042   704.064   49453.162   55.005
# 1987           11862.745   872.746   53534.533  102.676
# ...

# %% [markdown]
# **forest area (%of land)
# agriculture(% of land)**
